# %%
# !pip install boto3
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting boto3
#   Downloading boto3-1.26.135-py3-none-any.whl (135 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 135.6/135.6 kB 7.1 MB/s eta 0:00:00
# Collecting botocore<1.30.0,>=1.29.135 (from boto3)
#   Downloading botocore-1.29.135-py3-none-any.whl (10.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 91.5 MB/s eta 0:00:00
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3)
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3)
#   Downloading s3transfer-0.6.1-py3-none-any.whl (79 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.8/79.8 kB 8.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.10/dist-packages (from botocore<1.30.0,>=1.29.135->boto3) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /usr/local/lib/python3.10/dist-packages (from botocore<1.30.0,>=1.29.135->boto3) (1.26.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.30.0,>=1.29.135->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.26.135 botocore-1.29.135 jmespath-1.0.1 s3transfer-0.6.1

# %%
import os
import boto3
import sys
from prophet import Prophet
import matplotlib.pyplot as plt
import datetime
import pandas as pd

# %%
results = []

def history(client, instance, region_):
    INSTANCE = instance
    STARTTIME = (datetime.datetime.now() - datetime.timedelta(days=40)).isoformat()
    
    prices = client.describe_spot_price_history(
        InstanceTypes=[INSTANCE],
        ProductDescriptions=['Linux/UNIX'],
        AvailabilityZone="{region_}a".format(region_= region_),
        StartTime=STARTTIME,
        MaxResults=100
    )
    # print("Prices for region %s: %s" % (region, prices["SpotPriceHistory"]))
    for price in prices["SpotPriceHistory"]:
        results.append({
                        'Timestamp': price["Timestamp"].strftime('%m-%d-%Y'), 
                        'Price': price["SpotPrice"]
                        })

        
    df = pd.DataFrame.from_dict(results)
    df = df.rename(columns={'Timestamp': 'ds', 'Price': 'y'})
    df = df.sort_values('y', ascending=False).drop_duplicates('ds').sort_values('ds').reset_index(drop=True)
    
    return df

# %%
def interpolate(df):
    # Split the data into train and test sets
    # Train the model on the train set
    model = Prophet(
        daily_seasonality=True,
        yearly_seasonality=False,
    )
    model.fit(df)

    # Predict for the test set
    future = model.make_future_dataframe(periods=1)
    forecast = model.predict(future)
    predicted_prices = forecast['yhat'].iloc[-1]

    return predicted_prices

# %%
# Plot the actual and predicted values
def plot(df):
    plt.plot(df['ds'], df['y'], label='Actual')
    plt.plot(df['ds'], df['yhat'], label='Predicted')
    plt.xlabel('Date')
    plt.ylabel('Price')
    plt.title('Actual vs Predicted Prices')
    plt.legend()
    plt.show()

# %%
def main(instance):
    region = "us-east-1"
    client = boto3.client('ec2', region_name=region)
    df = history(client, instance, region)
    print(df)
    for i in range(len(df) - 21):
        print(f'Itertaion: {i}')
        new_df = df.iloc[i:i+21]
        print(f' new df start: {new_df.iloc[0]}')
        print(f' new df end: {new_df.iloc[-1]}')
        price = interpolate(new_df)
        df.loc[i+21, 'yhat'] = price
    print(df)
    return df

# %%
# spots = {"t2.small": {"cpu": 1, "memory": 2, "date": "2023-03-22", "cost": 0.008}, "t3.medium": {"cpu": 2, "memory": 4, "date": "2023-03-19", "cost": 0.019}, "m6g.medium": {"cpu": 1, "memory": 4, "date": 22, "cost": 0.01}, "c6a.large": {"cpu": 2, "memory": 4, "date": 22, "cost": 0.01}, "t4g.large": {"cpu": 2, "memory": 8, "date": 22, "cost": 0.01}, "c6g.xlarge": {"cpu": 4, "memory": 8, "date": 22, "cost": 0.01}}
# instances = list(spots.keys())
# print(instances)
# for i in instances:
#   print(f'Instance: {i}')
#   main(i)

updated_df = main('t2.small')
# Out:
#             ds         y
# 0   04-07-2023  0.013100
# 1   04-08-2023  0.013700
# 2   04-09-2023  0.014300
# 3   04-10-2023  0.014400
# 4   04-11-2023  0.014900
# 5   04-12-2023  0.015100
# 6   04-13-2023  0.015100
# 7   04-14-2023  0.015400
# 8   04-15-2023  0.015700
# 9   04-16-2023  0.015800
# 10  04-17-2023  0.016100
# 11  04-18-2023  0.016400
# 12  04-19-2023  0.016800
# 13  04-20-2023  0.017200
# 14  04-21-2023  0.017600
# 15  04-22-2023  0.017600
# 16  04-23-2023  0.017400
# 17  04-24-2023  0.017400
# 18  04-25-2023  0.017400
# 19  04-26-2023  0.017300
# 20  04-27-2023  0.017400
# 21  04-28-2023  0.017400
# 22  04-29-2023  0.017500
# 23  04-30-2023  0.017400
# 24  05-01-2023  0.017500
# 25  05-02-2023  0.017200
# 26  05-03-2023  0.017400
# 27  05-04-2023  0.017400
# 28  05-05-2023  0.017200
# 29  05-06-2023  0.017200
# 30  05-07-2023  0.017400
# 31  05-08-2023  0.017400
# 32  05-09-2023  0.017400
# 33  05-10-2023  0.017400
# 34  05-11-2023  0.017400
# 35  05-12-2023  0.017500
# 36  05-13-2023  0.017500
# 37  05-14-2023  0.017400
# 38  05-15-2023  0.017300
# 39  05-16-2023  0.017600
# 40  05-17-2023  0.017300
# Itertaion: 0
#  new df start: ds    04-07-2023
# y       0.013100
# Name: 0, dtype: object
#  new df end: ds    04-27-2023
# y       0.017400
# Name: 20, dtype: object
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# Initial log joint probability = -37.1796
# Iteration  1. Log joint probability =    28.9352. Improved by 66.1147.
# Iteration  2. Log joint probability =    41.9891. Improved by 13.0539.
# Iteration  3. Log joint probability =    55.0152. Improved by 13.0261.
# Iteration  4. Log joint probability =    66.2245. Improved by 11.2094.
# Iteration  5. Log joint probability =    69.9063. Improved by 3.68178.
# Iteration  6. Log joint probability =      70.57. Improved by 0.663652.
# Iteration  7. Log joint probability =    70.6094. Improved by 0.0394646.
# Iteration  8. Log joint probability =    70.6971. Improved by 0.0876393.
# Iteration  9. Log joint probability =    70.7318. Improved by 0.0347756.
# Iteration 10. Log joint probability =    71.0547. Improved by 0.322829.
# Iteration 11. Log joint probability =    71.2536. Improved by 0.198879.
# Iteration 12. Log joint probability =    71.3834. Improved by 0.129872.
# Iteration 13. Log joint probability =    71.5188. Improved by 0.135386.
# Iteration 14. Log joint probability =     71.528. Improved by 0.00918795.
# Iteration 15. Log joint probability =    71.8558. Improved by 0.327766.
# Iteration 16. Log joint probability =    73.6448. Improved by 1.78905.
# Iteration 17. Log joint probability =    74.0072. Improved by 0.362387.
# Iteration 18. Log joint probability =    74.2988. Improved by 0.291583.
# Iteration 19. Log joint probability =    74.3173. Improved by 0.0185435.
# Iteration 20. Log joint probability =    74.3362. Improved by 0.0188631.
# Iteration 21. Log joint probability =    74.5294. Improved by 0.193195.
# Iteration 22. Log joint probability =    75.5011. Improved by 0.971691.
# Iteration 23. Log joint probability =    76.2836. Improved by 0.78248.
# Iteration 24. Log joint probability =    78.9839. Improved by 2.70031.
# Iteration 25. Log joint probability =    81.7118. Improved by 2.72791.
# Iteration 26. Log joint probability =    82.2476. Improved by 0.535824.
# Iteration 73. Log joint probability =    91.1271. Improved by 2.91702e-05.
# Iteration 74. Log joint probability =    91.1272. Improved by 9.94541e-05.
# Iteration 75. Log joint probability =    91.1272. Improved by 1.79203e-05.
# Iteration 76. Log joint probability =    91.1272. Improved by 5.40736e-06.
# Iteration 77. Log joint probability =    91.1272. Improved by 6.77576e-06.
# Iteration 78. Log joint probability =    91.1272. Improved by 3.47065e-06.
# Iteration 79. Log joint probability =    91.1272. Improved by 1.94779e-06.
# Iteration 80. Log joint probability =    91.1272. Improved by 2.77599e-06.
# Iteration 81. Log joint probability =    91.1272. Improved by 5.43224e-07.
# Iteration 82. Log joint probability =    91.1272. Improved by 4.97103e-07.
# Iteration 83. Log joint probability =    91.1272. Improved by 1.11408e-06.
# Iteration 84. Log joint probability =    91.1272. Improved by 4.88658e-07.
# Iteration 85. Log joint probability =    91.1272. Improved by 2.58191e-07.
# Iteration 86. Log joint probability =    91.1272. Improved by 2.10951e-08.
# Iteration 87. Log joint probability =    91.1272. Improved by 4.28893e-07.
# Iteration 88. Log joint probability =    91.1272. Improved by 1.72151e-07.
# Iteration 89. Log joint probability =    91.1272. Improved by 2.30643e-07.
# Iteration 90. Log joint probability =    91.1272. Improved by 1.95886e-07.
# Iteration 91. Log joint probability =    91.1272. Improved by 1.22764e-07.
# Iteration 92. Log joint probability =    91.1272. Improved by 5.85432e-08.
# Iteration 93. Log joint probability =    91.1272. Improved by 3.78357e-08.
# Iteration 94. Log joint probability =    91.1272. Improved by 1.05172e-07.
# Iteration 95. Log joint probability =    91.1272. Improved by 1.2287e-09.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# Itertaion: 1
#  new df start: ds      04-08-2023
# y         0.013700
# yhat           NaN
# Name: 1, dtype: object
#  new df end: ds      04-28-2023
# y         0.017400
# yhat      0.017426
# Name: 21, dtype: object
#
# Initial log joint probability = -37.1758
# Iteration  1. Log joint probability =    29.4434. Improved by 66.6192.
# Iteration  2. Log joint probability =    37.7015. Improved by 8.25807.
# Iteration  3. Log joint probability =    54.0932. Improved by 16.3917.
# Iteration  4. Log joint probability =    65.2958. Improved by 11.2026.
# Iteration  5. Log joint probability =    69.7438. Improved by 4.44805.
# Iteration  6. Log joint probability =    70.0343. Improved by 0.29048.
# Iteration  7. Log joint probability =    70.0593. Improved by 0.0249775.
# Iteration  8. Log joint probability =    70.1119. Improved by 0.0526098.
# Iteration  9. Log joint probability =    70.1727. Improved by 0.0607891.
# Iteration 10. Log joint probability =    70.3026. Improved by 0.129971.
# Iteration 11. Log joint probability =    71.2221. Improved by 0.919512.
# Iteration 12. Log joint probability =    71.2961. Improved by 0.0739441.
# Iteration 13. Log joint probability =    71.3172. Improved by 0.0210944.
# Iteration 14. Log joint probability =    71.4844. Improved by 0.167248.
# Iteration 15. Log joint probability =     71.552. Improved by 0.0676096.
# Iteration 16. Log joint probability =    71.7362. Improved by 0.184157.
# Iteration 17. Log joint probability =    71.9596. Improved by 0.223444.
# Iteration 108. Log joint probability =    91.3287. Improved by 3.76132e-07.
# Iteration 109. Log joint probability =    91.3287. Improved by 1.02647e-07.
# Iteration 110. Log joint probability =    91.3287. Improved by 2.90514e-07.
# Iteration 111. Log joint probability =    91.3287. Improved by 7.60254e-08.
# Iteration 112. Log joint probability =    91.3287. Improved by 1.36751e-07.
# Iteration 113. Log joint probability =    91.3287. Improved by 5.52625e-08.
# Iteration 114. Log joint probability =    91.3287. Improved by 1.70517e-08.
# Iteration 115. Log joint probability =    91.3287. Improved by 1.32816e-08.
# Iteration 116. Log joint probability =    91.3287. Improved by 5.51849e-09.
# INFO:prophet:n_changepoints greater than number of observations. Using 15.
# Itertaion: 2
#  new df start: ds      04-09-2023
# y         0.014300
# yhat           NaN
# Name: 2, dtype: object
#  new df end: ds      04-29-2023
# y         0.017500
# yhat      0.017404
# Name: 22, dtype: object
#
# Initial log joint probability = -37.1704
# Iteration  1. Log joint probability =    30.1272. Improved by 67.2976.
# Iteration  2. Log joint probability =    44.9478. Improved by 14.8205.
# Iteration  3. Log joint probability =     57.711. Improved by 12.7632.
# Iteration  4. Log joint probability =    64.6027. Improved by 6.89171.
# Iteration  5. Log joint probability =    69.1798. Improved by 4.57709.
# Iteration  6. Log joint probability =    70.4837. Improved by 1.30387.
# Iteration  7. Log joint probability =    72.3376. Improved by 1.85392.
# Iteration  8. Log joint probability =    73.4379. Improved by 1.10028.
# Iteration  9. Log joint probability =    77.1426. Improved by 3.70477.
# Iteration 10. Log joint probability =    78.3239. Improved by 1.1813.
# Iteration 11. Log joint probability =    78.4366. Improved by 0.112638.
# Iteration 12. Log joint probability =    79.9271. Improved by 1.49055.
# Iteration 13. Log joint probability =    81.0338. Improved by 1.1067.
# Iteration 14. Log joint probability =    81.8474. Improved by 0.813582.
# Iteration 15. Log joint probability =    82.9701. Improved by 1.12268.
# Iteration 16. Log joint probability =    83.2905. Improved by 0.320411.
# Iteration 17. Log joint probability =    83.3043. Improved by 0.0137658.
# Iteration 18. Log joint probability =    83.5109. Improved by 0.206573.
# Iteration 19. Log joint probability =     83.524. Improved by 0.0131696.
# Iteration 20. Log joint probability =     83.588. Improved by 0.0639968.
# Iteration 21. Log joint probability =    83.7168. Improved by 0.128787.
# Iteration 22. Log joint probability =    83.7576. Improved by 0.0407771.
# Iteration 23. Log joint probability =    83.8088. Improved by 0.0512571.
# Iteration 24. Log joint probability =    83.8426. Improved by 0.0337642.
# Iteration 25. Log joint probability =    86.6851. Improved by 2.84249.
# Iteration 26. Log joint probability =    86.8755. Improved by 0.190428.
# Iteration 27. Log joint probability =    88.3971. Improved by 1.5216.
# Iteration 28. Log joint probability =    89.4561. Improved by 1.05899.
# Iteration 29. Log joint probability =     89.473. Improved by 0.0168933.
# Iteration 30. Log joint probability =    89.4972. Improved by 0.0242201.
# Iteration 31. Log joint probability =    89.5417. Improved by 0.0445211.
# Iteration 32. Log joint probability =    89.6339. Improved by 0.0921076.
# Iteration 33. Log joint probability =    89.6439. Improved by 0.010051.
# Iteration 34. Log joint probability =    89.7256. Improved by 0.0816596.
# Iteration 35. Log joint probability =    89.7353. Improved by 0.00968687.
# Iteration 36. Log joint probability =    89.8094. Improved by 0.074137.
# Iteration 37. Log joint probability =    89.8179. Improved by 0.00850672.
# Iteration 38. Log joint probability =    89.8812. Improved by 0.063329.
# Iteration 39. Log joint probability =    89.8875. Improved by 0.00623599.
# Iteration 40. Log joint probability =    89.9446. Improved by 0.0571553.
# Iteration 41. Log joint probability =    89.9491. Improved by 0.00451796.
# Iteration 42. Log joint probability =    90.0028. Improved by 0.0537048.
# Iteration 43. Log joint probability =    90.0078. Improved by 0.00501143.
# Iteration 44. Log joint probability =    90.0538. Improved by 0.0459708.
# Iteration 45. Log joint probability =    90.0565. Improved by 0.00271855.
# Iteration 46. Log joint probability =    90.1008. Improved by 0.0442891.
# Iteration 47. Log joint probability =    90.1017. Improved by 0.000904402.
# Iteration 48. Log joint probability =    90.1419. Improved by 0.0401535.
# Iteration 49. Log joint probability =    90.1431. Improved by 0.00117765.
# Iteration 50. Log joint probability =    90.1839. Improved by 0.040853.
# Iteration 51. Log joint probability =    90.2374. Improved by 0.0535203.
# Iteration 52. Log joint probability =    90.5452. Improved by 0.307775.
# Iteration 53. Log joint probability =    92.0911. Improved by 1.54586.
# Iteration 54. Log joint probability =    92.7863. Improved by 0.695238.
# Iteration 55. Log joint probability =    93.8623. Improved by 1.07604.
# Iteration 56. Log joint probability =    95.5193. Improved by 1.65692.
# Iteration 57. Log joint probability =    96.7104. Improved by 1.19112.
# Iteration 58. Log joint probability =    96.7272. Improved by 0.0168478.
# Iteration 59. Log joint probability =    97.8023. Improved by 1.07506.
# Iteration 60. Log joint probability =    97.8412. Improved by 0.0388857.
# Iteration 61. Log joint probability =    98.0446. Improved by 0.203459.
# Iteration 62. Log joint probability =    98.1108. Improved by 0.066126.
# Iteration 63. Log joint probability =    98.1219. Improved by 0.0111778.
# Iteration 64. Log joint probability =    98.1537. Improved by 0.0317806.
# Iteration 65. Log joint probability =    98.1625. Improved by 0.00880794.
# Iteration 66. Log joint probability =    98.5792. Improved by 0.416646.
# Iteration 67. Log joint probability =    98.6013. Improved by 0.022095.
# Iteration 68. Log joint probability =    98.6619. Improved by 0.0605865.
# Iteration 69. Log joint probability =    98.8639. Improved by 0.202058.
# Iteration 70. Log joint probability =    98.8774. Improved by 0.0134416.
# Iteration 71. Log joint probability =    98.8939. Improved by 0.0165007.
# Iteration 72. Log joint probability =    98.8991. Improved by 0.00520311.
# Iteration 73. Log joint probability =    98.9004. Improved by 0.0013327.
# Iteration 74. Log joint probability =    98.9018. Improved by 0.00136104.
# Iteration 75. Log joint probability =    98.9023. Improved by 0.000563525.
# Iteration 76. Log joint probability =     98.905. Improved by 0.00267194.
# Iteration 77. Log joint probability =    98.9065. Improved by 0.00147202.
# Iteration 78. Log joint probability =    98.9072. Improved by 0.000741884.
# Iteration 79. Log joint probability =     98.908. Improved by 0.00074851.
# Iteration 80. Log joint probability =    98.9093. Improved by 0.00132543.
# Iteration 81. Log joint probability =      98.91. Improved by 0.000714811.
# Iteration 82. Log joint probability =    98.9109. Improved by 0.000938772.
# Iteration 83. Log joint probability =    98.9111. Improved by 0.000121934.
# Iteration 84. Log joint probability =    98.9116. Improved by 0.00054557.
# Iteration 85. Log joint probability =    98.9117. Improved by 0.000124528.
# Iteration 86. Log joint probability =    98.9122. Improved by 0.000511736.
# Iteration 87. Log joint probability =    98.9126. Improved by 0.00035322.
# Iteration 88. Log joint probability =    98.9127. Improved by 0.000104553.
# Iteration 89. Log joint probability =    98.9129. Improved by 0.000158051.
# Iteration 90. Log joint probability =    98.9129. Improved by 1.81874e-05.
# Iteration 91. Log joint probability =     98.913. Improved by 0.000155362.
# Iteration 92. Log joint probability =    98.9131. Improved by 7.83405e-05.
# Iteration 93. Log joint probability =    98.9131. Improved by 1.20613e-05.
# Iteration 94. Log joint probability =    98.9132. Improved by 5.71125e-05.
# Iteration 95. Log joint probability =    98.9132. Improved by 3.9484e-05.
# Iteration 96. Log joint probability =    98.9132. Improved by 2.07427e-05.
# Iteration 97. Log joint probability =    98.9133. Improved by 1.925e-05.
# Iteration 98. Log joint probability =    98.9133. Improved by 3.37488e-05.
# Iteration 99. Log joint probability =    98.9133. Improved by 3.99295e-06.
# Iteration 100. Log joint probability =    98.9133. Improved by 1.11214e-05.
# Iteration 101. Log joint probability =    98.9133. Improved by 1.78721e-06.
# Iteration 102. Log joint probability =    98.9133. Improved by 2.18384e-07.
# Iteration 103. Log joint probability =    98.9133. Improved by 4.54304e-06.
# Iteration 104. Log joint probability =    98.9133. Improved by 3.2754e-07.
# Iteration 105. Log joint probability =    98.9133. Improved by 3.59312e-07.
# Iteration 106. Log joint probability =    98.9133. Improved by 2.58105e-07.
# Iteration 107. Log joint probability =    98.9133. Improved by 9.76003e-07.
# Iteration 108. Log joint probability =    98.9133. Improved by 9.13562e-07.
# Iteration 109. Log joint probability =    98.9133. Improved by 5.41813e-07.
# Iteration 110. Log joint probability =    98.9133. Improved by 1.38327e-06.
# Iteration 111. Log joint probability =    98.9133. Improved by 3.79754e-06.
# Iteration 112. Log joint probability =    98.9133. Improved by 5.63296e-07.
# Iteration 113. Log joint probability =    98.9133. Improved by 1.20245e-06.
# Iteration 114. Log joint probability =    98.9133. Improved by 4.90456e-06.
# Iteration 115. Log joint probability =    98.9133. Improved by 1.052e-07.
# Iteration 116. Log joint probability =    98.9133. Improved by 3.35737e-07.
# Iteration 117. Log joint probability =    98.9133. Improved by 9.05925e-08.
# Iteration 118. Log joint probability =    98.9133. Improved by 7.306e-07.
# Iteration 119. Log joint probability =    98.9133. Improved by 5.35184e-07.
# Iteration 120. Log joint probability =    98.9133. Improved by 2.06401e-07.
# Iteration 121. Log joint probability =    98.9133. Improved by 1.04096e-07.
# Iteration 122. Log joint probability =    98.9133. Improved by 1.73614e-07.
# Iteration 123. Log joint probability =    98.9133. Improved by 2.47409e-07.
# Iteration 124. Log joint probability =    98.9133. Improved by 3.59334e-07.
# Iteration 125. Log joint probability =    98.9133. Improved by 1.99371e-07.
# Iteration 126. Log joint probability =    98.9133. Improved by 3.0305e-08.
# Iteration 127. Log joint probability =    98.9133. Improved by 1.13655e-06.
# Iteration 128. Log joint probability =    98.9133. Improved by 3.69595e-08.
# Iteration 129. Log joint probability =    98.9133. Improved by 2.83173e-07.
# Iteration 130. Log joint probability =    98.9133. Improved by 1.62127e-07.
# Iteration 131. Log joint probability =    98.9133. Improved by 5.96675e-09.

# %%
plot(updated_df)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
updated_df
# Out:
#             ds         y      yhat
# 0   04-07-2023  0.013100       NaN
# 1   04-08-2023  0.013700       NaN
# 2   04-09-2023  0.014300       NaN
# 3   04-10-2023  0.014400       NaN
# 4   04-11-2023  0.014900       NaN
# 5   04-12-2023  0.015100       NaN
# 6   04-13-2023  0.015100       NaN
# 7   04-14-2023  0.015400       NaN
# 8   04-15-2023  0.015700       NaN
# 9   04-16-2023  0.015800       NaN
# 10  04-17-2023  0.016100       NaN
# 11  04-18-2023  0.016400       NaN
# 12  04-19-2023  0.016800       NaN
# 13  04-20-2023  0.017200       NaN
# 14  04-21-2023  0.017600       NaN
# 15  04-22-2023  0.017600       NaN
# 16  04-23-2023  0.017400       NaN
# 17  04-24-2023  0.017400       NaN
# 18  04-25-2023  0.017400       NaN
# 19  04-26-2023  0.017300       NaN
# 20  04-27-2023  0.017400       NaN
# 21  04-28-2023  0.017400  0.017426
# 22  04-29-2023  0.017500  0.017404
# 23  04-30-2023  0.017400  0.017257
# 24  05-01-2023  0.017500  0.017492
# 25  05-02-2023  0.017200  0.017622
# 26  05-03-2023  0.017400  0.017311
# 27  05-04-2023  0.017400  0.017465
# 28  05-05-2023  0.017200  0.017483
# 29  05-06-2023  0.017200  0.017354
# 30  05-07-2023  0.017400  0.017042
# 31  05-08-2023  0.017400  0.017245
# 32  05-09-2023  0.017400  0.017161
# 33  05-10-2023  0.017400  0.017279
# 34  05-11-2023  0.017400  0.017361
# 35  05-12-2023  0.017500  0.017406
# 36  05-13-2023  0.017500  0.017574
# 37  05-14-2023  0.017400  0.017600
# 38  05-15-2023  0.017300  0.017554
# 39  05-16-2023  0.017600  0.017232
# 40  05-17-2023  0.017300  0.017517

# %%
def plot2(df):
    # Create a figure and axis
    fig, ax = plt.subplots()

    # Plot the 'y' and 'y_hat' columns against the 'date' column
    ax.plot(df['ds'], df['y'], label='Actual')
    ax.plot(df['ds'], df['yhat'], label='Predicted')

    # Set the x-axis label
    ax.set_xlabel('Date')

    # Set the y-axis label
    ax.set_ylabel('Spot Price')

    # Set the title of the plot
    ax.set_title('Plot of actual and predicted')

    # Display a legend
    ax.legend()

    # Rotate x-axis labels for better readability (optional)
    plt.xticks(rotation=45)

    # Display the plot
    plt.show()

# %%
plot2(updated_df)
# Out:
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# INFO:matplotlib.category:Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.

# %%
updated_df.to_csv('t2_small.csv', index=False)
